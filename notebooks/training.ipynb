# %% [markdown]
# # Security Drift Intelligence - Model Training
# This notebook is a thin, reproducible entry point. Production logic remains in the backend modules.

# %%
from pathlib import Path
import sys
import pandas as pd

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT))
from backend.pipeline import DriftIntelligencePipeline

# %%
events = pd.read_csv(ROOT / 'data' / 'config_drift_events.csv')
pipeline = DriftIntelligencePipeline(ROOT / 'models')
metrics = pipeline.train(events)
metrics['cross_validation_f1_macro_mean']

# %%
scored = pipeline.score(events)
scored[['priority_level', 'priority_score', 'anomaly_flag']].head()
